# %% [markdown]
# # Predicting movie reviews with a three-layer neural network (from scratch)

# %%
import sys
import numpy as np

np.random.seed(1)

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

# %%
f = open('reviews.txt', 'r')
review_tokens = list(filter(lambda x: x not in ['', '\n'], map(lambda x: set(x.split(' ')), f.readlines())))
f.close()

f = open('labels.txt', 'r')
labels = [1 if label == 'positive\n' else 0 for label in f.readlines()]
f.close()

vocab = set()
for sentence in review_tokens:
    for word in sentence:
        if len(word) > 0:
            vocab.add(word)
vocab = list(vocab)

word_to_index = {}
for word_index, word in enumerate(vocab):
    word_to_index[word] = word_index

reviews = []
for sentence in review_tokens:
    sentence_indices = []
    for word in sentence:
        try:
            sentence_indices.append(word_to_index[word])
        except KeyError:
            pass
    reviews.append(list(set(sentence_indices)))

# features = np.array([[1 if word_index == word_to_index[word] else 0 for word_index, word in enumerate(vocab)] for review in reviews])
one_hot_matrix = []
for review in reviews:
    one_hot_vector = [0 for _ in range(len(vocab))]
    for word_index in review:
        one_hot_vector[word_index] = 1
    one_hot_matrix.append(one_hot_vector)
features = np.array(one_hot_matrix)

# %%
# np.save('review_features', features)
# np.save('review_labels', labels)

# %%
# features = np.load('review_features')
# labels = np.load('review_labels')

# %%
alpha, num_of_epochs, input_size, hidden_size, output_size, correct, total = (0.01, 300, len(vocab), 5, 1, 0, 0)
weights_0_1 = 2 * np.random.random((input_size, hidden_size)) - 1
weights_1_2 = 2 * np.random.random((hidden_size, output_size)) - 1

# %%
for epoch in range(num_of_epochs):
    error = 0
    total_error_squared = 0
    for i in range(int(len(features) * 0.8)):
        layer_0 = features[i:i + 1]
        layer_1 = sigmoid(np.dot(layer_0, weights_0_1))
        layer_2 = np.dot(layer_1, weights_1_2)

        error = layer_2 - labels[i:i + 1]
        layer_2_delta = error

        layer_1_delta = np.dot(layer_2_delta, weights_1_2.T)

        weights_1_2 -= alpha * np.dot(layer_1.T, layer_2_delta)
        weights_0_1 -= alpha * np.dot(layer_0.T, layer_1_delta)

        if np.abs(layer_2_delta) < 0.5:
            correct += 1
        total += 1

        if i % 10 == 9:
            progress = str(i/float(len(features)))
            sys.stdout.write('\rIteration:'+str(iter)\
                             +' Progress:'+progress[2:4]\
                             +'.'+progress[4:6]\
                             +'% Training Accuracy:'\
                             + str(correct/float(total)) + '%')
    print()

correct, total = (0,0)
for i in range(int(len(features) * 0.8), len(features)):

    x = features[i:i + 1]
    y = labels[i:i + 1]

    layer_1 = sigmoid(np.sum(weights_0_1, axis=0))
    layer_2 = sigmoid(np.dot(layer_1, weights_1_2))

    if np.abs(layer_2 - y) < 0.5:
        correct += 1
    total += 1
print("Test Accuracy:" + str(correct / float(total)))
# Out:
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.5%42857142857142%%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.55%3333333333333%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.5791666666666667%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.60625%806451613%%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.635%333333333333%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.6666666666666666%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.6910714285714286%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.7125%38095238096%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.7291666666666666%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.7425%6329113924%%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.7556818181818182%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.7677083333333333%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.7788461538461539%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.7883928571428571%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.7983333333333333%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.8078125%25984252%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.8169117647058823%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.8256944444444444%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.8328947368421052%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.839375%798742139%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.8452380952380952%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.8517045454545454%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.8576086956521739%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.8630208333333333%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.868%366834170855%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.8725961538461539%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.8768518518518519%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.8808035714285715%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.8844827586206897%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.8879166666666667%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.8911290322580645%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.894140625%960784%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.896969696969697%%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9%96309963099631%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9028571428571428%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9055555555555556%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9081081081081082%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9105263157894737%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9128205128205128%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.915%335423197492%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9170731707317074%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.919047619047619%%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9209302325581395%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9227272727272727%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9244444444444444%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9260869565217391%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9276595744680851%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9291666666666667%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9306122448979591%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.932%295739348371%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9333333333333333%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9346153846153846%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9358490566037736%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.937037037037037%%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9381818181818182%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9392857142857143%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9403508771929825%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9413793103448276%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9423728813559322%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9433333333333334%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9442622950819672%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9451612903225807%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.946031746031746%%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.946875%371819961%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9476923076923077%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9484848484848485%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9492537313432836%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.95%9079189686924%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9507246376811594%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9514285714285714%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.952112676056338%%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.9527777777777777%
# Iteration:<built-in function iter> Progress:79.% Training Accuracy:0.